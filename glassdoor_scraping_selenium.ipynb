# %%
import pandas as pd
import numpy as np
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, ElementNotInteractableException, StaleElementReferenceException

# %%
# Create a function to scrape job postings
def scraping_jobs(keyword, num_pages):
    
    # Create a list to contain the scraped job posting info
    jobs=[]
    
    # scrape job postings nationwide
    state_names = ["Alaska", "Alabama", "Arkansas", "Arizona", "California", 
               "Colorado", "Connecticut", "Washington, DC", "Delaware", "Florida", 
               "Georgia", "Hawaii", "Iowa", "Idaho", "Illinois",
               "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", 
               "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", 
               "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", 
               "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", 
               "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", 
               "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", 
               "Virginia", "Vermont", "Washington State", "Wisconsin", "West Virginia", 
               "Wyoming"]
    
    # Open Chrome using webdriver
    driver = webdriver.Chrome(r"C:\Users\hannah\chromedriver.exe")
    
    # Go to the job search page in the Glassdoor
    url = "https://www.glassdoor.com/Job/index.htm"
    driver.get(url)
    
    # Enter the job key word 'data analyst' in th search box
    search_job = driver.find_element_by_xpath('//input[@class="keyword"]')
    search_job.send_keys([keyword])
    
    
    for location in state_names:
        
        # Enter the state name in the location box
        search_location = driver.find_element_by_xpath('//input[@class="loc"]')
        search_location.clear()
        search_location.send_keys([location])
    
        # Click the search button
        search_button = driver.find_element_by_xpath('//button[@id="HeroSearchButton"]')
        search_button.click()
        
        page = 1
        
        
        # loop until the page reaches the page number you set
        while page <= num_pages:
            
            # wait until the job postings are completely opened in the screen (4 seconds) 
            time.sleep(4)
            
            # First click the selected job posting
            driver.find_element_by_class_name("selected").click()
            time.sleep(1)
            
            # Close the pop-up window to ask you to log in the site
            try:
                driver.find_element_by_xpath("//*[@id='JAModal']/div/div[2]/span").click()
            except NoSuchElementException:
                pass
        
            # Find the job posting elements (about 30 postings) and store into the 'job_buttons'
            job_buttons = driver.find_elements_by_class_name("jl")
    
            # loop for each jop posting
            for job_button in job_buttons:
                
                # Click the job posting
                try:
                    job_button.click()
                except (ElementNotInteractableException, StaleElementReferenceException):
                    pass
                
                # Wait for the relevant job posting to be downloaded in the screen
                time.sleep(1)
        
                # Scrape the name of the company for the posting
                try:
                    company = driver.find_element_by_xpath('.//div[@class="employerName"]').text.split('\n')[0]
                except IndexError:
                    company = ''
                    
                # Scrape the job title    
                try:    
                    title = driver.find_element_by_xpath('.//div[contains(@class, "title")]').text
                except IndexError:
                    title = ''
                    
                # Scrape the location of the job    
                try:
                    location = driver.find_element_by_xpath('.//div[@class="location"]').text
                except IndexError:
                    location = ''
            
                # Scrape the salary information for the job
                try:
                    salary = driver.find_element_by_xpath('.//div[@class="salary"]/span').text.split()[0]
                except NoSuchElementException:
                    salary = ""
                    
                # Scrape the rating of the company    
                try:
                    rating = driver.find_element_by_xpath('.//span[@class="rating"]').text
                except NoSuchElementException:
                    rating = np.nan
                   
                # Scrape the job description
                try:
                    job_description = driver.find_element_by_xpath('.//div[@class="jobDescriptionContent desc"]').text
                except NoSuchElementException:
                    job_description = ''
                    
                # Open the company info page    
                try:
                    driver.find_element_by_xpath('.//div[@class="tab" and @data-tab-type="overview"]').click()
                    time.sleep(.3)
                    
                    lists=[]
                    
                    # Check what kind of info for the company is in the company info page
                    for i in range(1,len(driver.find_elements_by_xpath('//div[@class="info row"]/div'))+1):
                        s = driver.find_element_by_xpath('//div[@class="info row"]/div[{}]/label'.format(i)).text
                        lists.append(s)
                        
                    # Scrape company size    
                    try:
                        if 'Size' in lists:
                            s = lists.index('Size') + 1
                            size = driver.find_element_by_xpath('//div[@class="info row"]/div[{}]/span[@class="value"]'.format(s)).text
                        else:
                            size = ''
                    except NoSuchElementException:
                        size = ''
                        
                    # Scrape the industry which the company belongs to    
                    try:
                        if 'Industry' in lists:
                            d = lists.index('Industry') + 1
                            industry = driver.find_element_by_xpath('//div[@class="info row"]/div[{}]/span[@class="value"]'.format(d)).text
                        else:
                            industry = ''
                    except NoSuchElementException:
                        industry = ''
                        
                    # Scrape the sector which the company belongs to    
                    try:
                        if 'Sector' in lists:
                            e = lists.index('Sector') + 1
                            sector = driver.find_element_by_xpath('//div[@class="info row"]/div[{}]/span[@class="value"]'.format(e)).text
                        else:
                            sector = ''
                    except NoSuchElementException:
                        sector = ''
                        
                    # Scrape the revenue info     
                    try:
                        if 'Revenue' in lists:
                            r = lists.index('Revenue') + 1
                            revenue = driver.find_element_by_xpath('//div[@class="info row"]/div[{}]/span[@class="value"]'.format(r)).text
                        else:
                            revenue = ''
                    except NoSuchElementException:
                        revenue = ''
                        
                        
                except NoSuchElementException:
                    size = ''
                    industry = ''
                    sector = ''
                    revenue = ''
            
                # Put the scraped info from the job posting into the list named 'jobs'
                jobs.append({'company':company, 
                             'title':title, 
                             'location':location, 
                             'salary':salary, 
                             'rating':rating, 
                             'size':size,
                             'industry':industry,
                             'sector':sector,
                             'revenue':revenue,
                             'job_description':job_description})
            
            page += 1
            
            # Go to the next page
            try:
                driver.find_element_by_xpath('.//li[@class="next"]//a').click()
            except NoSuchElementException:
                break
            
    return pd.DataFrame(jobs)

# %%
# Run the function 'scraping_jobs' with the key word 'data analyst' and the page number 3
df = scraping_jobs('data analyst', 3)

# %%
df.head(50)
# Out:
#                                 company  \
# 0                                   CTG
# 1                  Manmade Creative Inc
# 2                   DS Technologies Inc
# 3                 Integrated Statistics
# 4               Southcentral Foundation
# 5         National Renewable Energy Lab
# 6       Alaska USA Federal Credit Union
# 7            General Communication Inc.
# 8       Alaska USA Federal Credit Union
# 9                            Austal USA
# 10                      McLeod Software
# 11                            CompQsoft
# 12                                HyreU
# 13                             Intrepid
# 14                                 BBVA
# 15                                  LMI
# 16                    LSINC Corporation
# 17                Guardian Credit Union
# 18                           RiverPoint
# 19            22nd Century Technologies
# 20                              S3, Inc
# 21                     Northrop Grumman
# 22                    Motion Industries
# 23                       LSI Consulting
# 24                                COLSA
# 25                                COLSA
# 26          East Alabama Medical Center
# 27                    Rezult Technology
# 28                    Auburn University
# 29                WILL Technology, Inc.
# 30                                 BBVA
# 31                         Leonardo DRS
# 32                   Daylight Solutions
# 33             Unclaimed Baggage Center
# 34                           Tetra Tech
# 35               deciBel Research, Inc.
# 36  University of Alabama at Birmingham
# 37                  M1 Support Services
# 38                                DISYS
# 39                                Shipt
# 40                       LSI Consulting
# 41                          Better Hire
# 42                         UAB Medicine
# 43                                  ATJ
# 44                         UAB Medicine
# 45          LOCKHEED MARTIN CORPORATION
# 46                      Lockheed Martin
# 47                              Sanmina
# 48                                Shipt
# 49                                Shipt
#
#                                                 title         location  \
# 0                      DATA CENTER SERVICES ANALYST I    Anchorage, AK
# 1                             DATA ANALYST and HEALTH    Anchorage, AK
# 2                                        Data Analyst           Alaska
# 3                                Data Analyst/Modeler    Anchorage, AK
# 4                                        Data Analyst    Anchorage, AK
# 5   Cold Climate Data Researcher / Analyst II (Ala...    Fairbanks, AK
# 6   Data Center Services Analyst I, II, III, or Se...    Anchorage, AK
# 7                   Analyst, Network Statistical Data    Anchorage, AK
# 8                     Data Center Services Analyst II    Anchorage, AK
# 9                                    HCM Data Analyst       Mobile, AL
# 10                            Operations Data Analyst   Birmingham, AL
# 11                                       Data Analyst   Huntsville, AL
# 12                                       Data Analyst          Alabama
# 13                              Business/Data Analyst   Huntsville, AL
# 14                              Data Strategy Analyst   Birmingham, AL
# 15                  Data Analyst - Clearance Required   Huntsville, AL
# 16                          Intermediate Data Analyst   Huntsville, AL
# 17                                       DATA ANALYST   Montgomery, AL
# 18                                       Data Analyst        Plano, AL
# 19                               Data Quality Analyst   Montgomery, AL
# 20                            Data Management Analyst   Huntsville, AL
# 21                            Data Management Analyst   Huntsville, AL
# 22  Product Information Management (PIM) Data Analyst     Irondale, AL
# 23  LSI Grow, Entry Level SAP Data Migration Analy...          Alabama
# 24          Configuration and Data Management Analyst   Huntsville, AL
# 25                       Data Analyst / Data Engineer   Huntsville, AL
# 26                  CIN DATA ANALYST - DATA INTEGRITY      Opelika, AL
# 27                             Financial Data Analyst   Birmingham, AL
# 28  Spec IV, Info Tech (Business Analyst - Data Ma...       Auburn, AL
# 29                                       Data Analyst   Huntsville, AL
# 30                          Data Strategy Analyst, Sr   Birmingham, AL
# 31                            Data Management Analyst   Huntsville, AL
# 32                            Data Management Analyst   Huntsville, AL
# 33                                Senior Data Analyst   Scottsboro, AL
# 34                  Data Quality Analyst (Baldwin Co)       Daphne, AL
# 35                            Radar Data Analyst: BGI   Huntsville, AL
# 36                                   Data Analyst-GME   Birmingham, AL
# 37       Maintenance Data Analyst - Air Force Project  Fort Rucker, AL
# 38                     Jr. Data Analyst or Technician       Hoover, AL
# 39                              Data Analyst - Retail   Birmingham, AL
# 40  SAP Data Migration Analyst (US citizen or Perm...          Alabama
# 41                          Data Analyst-cool company   Birmingham, AL
# 42                              Data Analyst-GME (Day   Birmingham, AL
# 43                     Senior Data Analyst Newspapers     McMullen, AL
# 44                                   Data Analyst-GME   Birmingham, AL
# 45       Production Systems Analyst / Data Analysis /         Troy, AL
# 46  Production Systems Analyst / Data Analysis / T...         Troy, AL
# 47                                Senior Data Analyst   Huntsville, AL
# 48                                 Data Analyst - CPG   Birmingham, AL
# 49                                  Data Analyst, CPG   Birmingham, AL
#
#         salary rating                     size  \
# 0                 3.4   1001 to 5000 Employees
# 1                 NaN
# 2                 5.0        1 to 50 Employees
# 3    $48K-$86K    5.0      51 to 200 Employees
# 4    $39K-$68K    3.5   1001 to 5000 Employees
# 5   $67K-$148K    3.9   1001 to 5000 Employees
# 6    $26K-$48K    3.4   1001 to 5000 Employees
# 7   $43K-$101K    3.7   1001 to 5000 Employees
# 8    $36K-$69K    3.4   1001 to 5000 Employees
# 9    $55K-$94K    3.1   1001 to 5000 Employees
# 10   $38K-$70K    4.2     201 to 500 Employees
# 11   $59K-$80K    3.5      51 to 200 Employees
# 12                1.0                  Unknown
# 13   $43K-$79K    4.3      51 to 200 Employees
# 14   $40K-$65K    3.7         10000+ Employees
# 15   $33K-$60K    4.3   1001 to 5000 Employees
# 16                3.8      51 to 200 Employees
# 17   $30K-$54K    2.9      51 to 200 Employees
# 18                4.0        1 to 50 Employees
# 19   $38K-$71K    3.4   1001 to 5000 Employees
# 20   $30K-$61K    4.0     201 to 500 Employees
# 21   $27K-$56K    3.9         10000+ Employees
# 22   $39K-$68K    3.9  5001 to 10000 Employees
# 23                4.7      51 to 200 Employees
# 24   $29K-$59K    4.2   1001 to 5000 Employees
# 25   $47K-$84K    4.2   1001 to 5000 Employees
# 26   $34K-$59K    3.6   1001 to 5000 Employees
# 27                4.9     201 to 500 Employees
# 28   $32K-$64K    4.5  5001 to 10000 Employees
# 29                2.7      51 to 200 Employees
# 30   $49K-$80K    3.7         10000+ Employees
# 31   $29K-$60K    3.6  5001 to 10000 Employees
# 32                4.8      51 to 200 Employees
# 33                3.4      51 to 200 Employees
# 34   $35K-$61K    3.7         10000+ Employees
# 35                3.4      51 to 200 Employees
# 36   $33K-$60K    4.2         10000+ Employees
# 37   $44K-$80K    3.9      51 to 200 Employees
# 38   $41K-$77K    3.4   1001 to 5000 Employees
# 39   $36K-$68K    3.7   1001 to 5000 Employees
# 40                4.7      51 to 200 Employees
# 41   $26K-$71K    4.0        1 to 50 Employees
# 42   $38K-$68K    3.9         10000+ Employees
# 43                4.4   1001 to 5000 Employees
# 44   $38K-$68K    3.9         10000+ Employees
# 45   $35K-$66K    3.9         10000+ Employees
# 46   $35K-$66K    3.9         10000+ Employees
# 47   $41K-$70K    3.1         10000+ Employees
# 48   $34K-$65K    3.7   1001 to 5000 Employees
# 49   $34K-$65K    3.7   1001 to 5000 Employees
#
#                                  industry                        sector  \
# 0                             IT Services        Information Technology
# 1
# 2
# 3               Health, Beauty, & Fitness             Consumer Services
# 4                Membership Organizations             Business Services
# 5                                  Energy  Oil, Gas, Energy & Utilities
# 6                   Banks & Credit Unions                       Finance
# 7   Cable, Internet & Telephone Providers            Telecommunications
# 8                   Banks & Credit Unions                       Finance
# 9                Industrial Manufacturing                 Manufacturing
# 10              Transportation Management    Transportation & Logistics
# 11                            IT Services        Information Technology
# 12
# 13                    Aerospace & Defense           Aerospace & Defense
# 14                  Banks & Credit Unions                       Finance
# 15                             Consulting             Business Services
# 16   Architectural & Engineering Services             Business Services
# 17                  Banks & Credit Unions                       Finance
# 18                             Accounting            Accounting & Legal
# 19                            IT Services        Information Technology
# 20   Architectural & Engineering Services             Business Services
# 21                    Aerospace & Defense           Aerospace & Defense
# 22                              Wholesale             Business Services
# 23                             Consulting             Business Services
# 24                 Research & Development             Business Services
# 25                 Research & Development             Business Services
# 26       Health Care Services & Hospitals                   Health Care
# 27                 Staffing & Outsourcing             Business Services
# 28                Colleges & Universities                     Education
# 29
# 30                  Banks & Credit Unions                       Finance
# 31                    Aerospace & Defense           Aerospace & Defense
# 32                    Aerospace & Defense           Aerospace & Defense
# 33
# 34   Architectural & Engineering Services             Business Services
# 35                    Aerospace & Defense           Aerospace & Defense
# 36                Colleges & Universities                     Education
# 37
# 38                            IT Services        Information Technology
# 39                Consumer Product Rental             Consumer Services
# 40                             Consulting             Business Services
# 41
# 42       Health Care Services & Hospitals                   Health Care
# 43                             Consulting             Business Services
# 44       Health Care Services & Hospitals                   Health Care
# 45                    Aerospace & Defense           Aerospace & Defense
# 46                    Aerospace & Defense           Aerospace & Defense
# 47  Electrical & Electronic Manufacturing                 Manufacturing
# 48                Consumer Product Rental             Consumer Services
# 49                Consumer Product Rental             Consumer Services
#
#                              revenue  \
# 0         $100 to $500 million (USD)
# 1
# 2             $1 to $5 million (USD)
# 3            $5 to $10 million (USD)
# 4         $100 to $500 million (USD)
# 5           Unknown / Non-Applicable
# 6         $100 to $500 million (USD)
# 7   $500 million to $1 billion (USD)
# 8         $100 to $500 million (USD)
# 9             $1 to $2 billion (USD)
# 10          $10 to $25 million (USD)
# 11          $10 to $25 million (USD)
# 12        Less than $1 million (USD)
# 13         $50 to $100 million (USD)
# 14            $2 to $5 billion (USD)
# 15        $100 to $500 million (USD)
# 16          $10 to $25 million (USD)
# 17        $100 to $500 million (USD)
# 18           $5 to $10 million (USD)
# 19          $25 to $50 million (USD)
# 20          Unknown / Non-Applicable
# 21                $10+ billion (USD)
# 22            $2 to $5 billion (USD)
# 23            $1 to $5 million (USD)
# 24        $100 to $500 million (USD)
# 25        $100 to $500 million (USD)
# 26        $100 to $500 million (USD)
# 27          Unknown / Non-Applicable
# 28  $500 million to $1 billion (USD)
# 29           $5 to $10 million (USD)
# 30            $2 to $5 billion (USD)
# 31            $1 to $2 billion (USD)
# 32          $25 to $50 million (USD)
# 33        Less than $1 million (USD)
# 34            $2 to $5 billion (USD)
# 35          Unknown / Non-Applicable
# 36            $1 to $2 billion (USD)
# 37           $5 to $10 million (USD)
# 38        $100 to $500 million (USD)
# 39          Unknown / Non-Applicable
# 40            $1 to $5 million (USD)
# 41        Less than $1 million (USD)
# 42          Unknown / Non-Applicable
# 43           $5 to $10 million (USD)
# 44          Unknown / Non-Applicable
# 45                $10+ billion (USD)
# 46                $10+ billion (USD)
# 47           $5 to $10 billion (USD)
# 48          Unknown / Non-Applicable
# 49          Unknown / Non-Applicable
#
#                                       job_description
# 0   CTG is searching for a full time *Data Center ...
# 1   Familiarity in analysis reporting, data entry,...
# 2   Hi,Greetings from DSTechnologiesinc!\n\nIam re...
# 3   Data Analyst/Modeler Needed\n\nIntegrated Stat...
# 4   The Southcentral Foundation (SCF) Data Analyst...
# 5   Posting TitleCold Climate Data Researcher / An...
# 6   Reports to: Varies by location\n\nFunctions Su...
# 7   GCI's Network Statistical Data Analyst will pr...
# 8   Reports to: Varies by location\n\nFunctions Su...
# 9   Any qualified individual with a disability who...
# 10  McLeod Software is the leading developer and p...
# 11  CompQsoft Inc. Established in 1997, headquarte...
# 12  QUALIFICATION REQUIRED Bachelor Degree\nEXPERI...
# 13  Intrepid sets the standard for delivering exce...
# 14  Area:\nDATA\n\nDeadline for applying:\n11/28/2...
# 15  LMI is seeking a skilled Junior Data Analyst i...
# 16  LSINC Corporation is a dynamic, innovative fir...
# 17  Role\n\nCombines advanced statistical, analyti...
# 18  The Data Analyst is responsible for, but not l...
# 19  Job Title: Data Quality Analyst\nLocation: Mon...
# 20  Data Management Analyst\nDuty Site\n\n\nRedsto...
# 21  The Data Management Analyst: Supports business...
# 22  SUMMARY\n\nResponsible for executing a structu...
# 23  Jumpstart your career with LSI Grow!\n\nAre yo...
# 24  Tracking Code\n\n5470-987\n\nJob Description\n...
# 25  General Summary\n\nPerforms analyst functions ...
# 26  Position Name\n\n18400 – CIN Data Analyst\n\nP...
# 27  Posted Date: 11/26/2019\nJob Category: Computi...
# 28  Position Details\n\nRequisition Number S461P\n...
# 29  WILL Technology, Inc. (WTI) has an immediate n...
# 30  Area:\nDATA\n\nDeadline for applying:\n11/28/2...
# 31  Job ID : 99487\n\nThe Leonardo DRS Land Electr...
# 32  Job ID: 99487\n\nThe Leonardo DRS Land Electro...
# 33  *** There are no funds for relocation for this...
# 34  Are you ready to take the next step in your ca...
# 35  deciBel Research has an immediate opening for ...
# 36  To design, maintain, and troubleshoot the Grad...
# 37  _Maintenance Data Analyst – Air Force Project_...
# 38  Qualifications: *\nProblem Solving\nRelational...
# 39  Shipt is a membership-based marketplace that h...
# 40  Responsibilities\nAccountable for the successf...
# 41  We are looking for a Data Analyst who can crea...
# 42  Data Analyst-GME (Day) #002\n(T179348)\nTo des...
# 43  IMPORTANT NOTE: ATJ is not a real company. It ...
# 44  To design, maintain, and troubleshoot the Grad...
# 45  Lockheed Martin Missiles and Fire Control’s (M...
# 46  Description:Lockheed Martin Missiles and Fire ...
# 47  Sanmina Corporation (Nasdaq: SANM) is a leadin...
# 48  Shipt is a membership-based marketplace that h...
# 49  Shipt is a membership-based marketplace that h...

# %%
# Store the scraped job posting info as the csv file
df.to_csv(r'...\glassdoor_data_analyst.csv', index=False)
